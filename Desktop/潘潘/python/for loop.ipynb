# %%
num =[23, 4, 53, 5, 35, 6]

# %%
print(min(num))
print(max(num))
# Out:
# 4
# 53

# %%
print(sum(num))
# Out:
# 126

# %%
#用for loop 計算 num list 的總值

# %%
sum = 0
for i in num:
    sum=sum +i
print(sum)
# Out:
# 126

# %%
a= num.index(

# %%
for i in num:
    print(i)
# Out:
# 23
# 4
# 53
# 5
# 35
# 6

# %%
for i , j in enumerate(num):
    print(i, j )
# Out:
# 0 23
# 1 4
# 2 53
# 3 5
# 4 35
# 5 6
