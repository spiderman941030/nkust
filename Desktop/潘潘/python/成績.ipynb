# %%
a = input("輸入：")
# Out:
# 輸入： 60

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
b = int(a) 
print(type(b))
# Out:
# <class 'int'>

# %%
score = int(input ("輸入："))
if score >= 60:
    print ("成績及格")
else:
    print("不及格")
# Out:
# 輸入： 44
# 不及格

# %%
x = input("輸入x:")
y = input("輸入y:")

if x>y:
    print("max", x)
else:
    print("max", y)
# Out:
# 輸入x: 22222
# 輸入y: 67890987654
# max 67890987654

# %%
score = int(input ("輸入："))
if score >= 90:
    print("A")
elif score >= 80:
    print ("B")
elif score >= 70:
    print ("C")
elif score >= 60:
    print ("D")
else :
    print ("F")
# Out:
# 輸入： 55
# F

# %%
ID = input("學號:")
year =int (ID[2:4])
if year < 11:
    print("Graduted")
elif year <=14 and year >=11:
    if year == 14:
        print ("大一")
    elif year == 13:
        print ("大二")
    elif year ==12:
        print("大三")
    elif year == 11:
        print ("大四")
    else:
        print ("你未註冊")
# Out:
# 學號: C111190112
# 大四
