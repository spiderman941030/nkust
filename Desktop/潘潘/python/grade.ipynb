# %%
a=input("請輸入成績:"）
# Out:
#   Cell In[1], line 1
#     a=input(‘請輸入成績:’）
#             ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
print(type(a))

# %%
b = int(a) 
print(type(b))

# %%
score = int(input ("請輸入成績：”）)]
if score >= 60:
    print (“成績及格！）
