# %%
x = 1
print(x)
print(type(x))
# Out:
# 1
# <class 'int'>

# %%
x = 1
print(x)
print(type(x))
# Out:
# 1
# <class 'int'>

# %%
x = 1.5
print(x)
print(type(x))
# Out:
# 1.5
# <class 'float'>

# %%
a = True
print (a)
print (type(a))
# Out:
# True
# <class 'bool'>

# %%
a = 1
b = 2
c = a == b
print (c)
# Out:
# False

# %%
print('"Hi" python')
# Out:
# "Hi" python

# %%
b ='"hi" python'

# %%
print(b)
# Out:
# 2

# %%
a = "Hi"
b = " Python"
print(a + b)
# Out:
# Hi Python

# %%
print(a*3)
# Out:
# HiHiHi

# %%
y = len(b)
print(y)
# Out:
# 7

# %%
print(b[3])
# Out:
# t

# %%
print(b[1:4])
# Out:
# Pyt

# %%
floatNum = 55.0
print(floatNum)
print(type(floatNum))
# Out:
# 55.0
# <class 'float'>

# %%
intNum = int(floatNum)
print(intNum)
print(type(intNum))
# Out:
# 55
# <class 'int'>

# %%
strNum ="55"
print(strNum)
print(type(strNum))
# Out:
# 55
# <class 'str'>

# %%
intNum = int(strNum)
print(intNum)
print (type(intNum))
# Out:
# 55
# <class 'int'>

# %%
strNum ="55.55"
print(strNum)
print(type(strNum))
# Out:
# 55.55
# <class 'str'>

# %%
intNum = int(strNum)
print(intNum)
print (type(intNum))
# Out:
# 55
# <class 'int'>
